# %%
a = 5
# print(a)
a
# Out:
# 5

# %%
print('Hello world')
# Out:
# Hello world

# %%
# arbitary python statements, it gives string representation of output
import numpy as np
data = {i : np.random.randn() for i in range(7)}
data
# Out:
# {0: -0.37062118773794406,
#  1: -0.19125319732252374,
#  2: 0.6457038984725956,
#  3: 1.6077874996053252,
#  4: -0.6583760778507416,
#  5: 0.6660461895553293,
#  6: 1.0912844760670322}

# %%
from numpy.random import randn
data = {i : randn() for i in range(7)}
print(data)
# Out:
# {0: -0.6958156483090965, 1: -1.247434839974802, 2: 0.4393822823802905, 3: 1.6133326917866502, 4: -0.41913744382510887, 5: 1.1971802967564313, 6: 0.24156282933873374}

# %%
# In jupyter notebook
print('Hello, world!')
# Out:
# Hello, world!

# %%
# In jupyter notebook
# %pwd
# Out:
# '/work'

# %%
# Tab function
b = [2, 5, 3]
b.append(4)
b
# Out:
# [2, 5, 3, 4]

# %%
b.sort()
b
# Out:
# [2, 3, 4, 5]

# %%
b.pop()
b
# Out:
# [2, 3, 4]

# %%
b.reverse()
b
# Out:
# [4, 3, 2]

# %%
b = [2,3,5,6,3]
c = b.count(3)
c
# Out:
# 2

# %%
b = [1,2,3]
b.insert(0,5)
b
# Out:
# [5, 1, 2, 3]

# %%
b.remove(2)
b
# Out:
# [5, 1, 3]

# %%
a = b.copy()
a
# Out:
# [5, 1, 3]

# %%
a = [1,2,3]
b = [4,5,6]
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a.clear()
a
# Out:
# []

# %%
# Tab function
import datetime
x = datetime.MAXYEAR
y = datetime.MINYEAR
print(x)
print(y)
# Out:
# 9999
# 1

# %%
a = datetime.datetime(2020,5,12,11,3,55)
b = datetime.date(2021, 1,11)
print(a)
print(b)
# Out:
# 2020-05-12 11:03:55
# 2021-01-11

# %%
c = datetime.timedelta(days=10,hours=11,seconds=54,minutes=45)
print(c)
# Out:
# 10 days, 11:45:54

# %%
# Using Functions
def add_numbers(a,b):
    return a+b

#a = int(input("enter a number: "))
#b = int(input("enter a number: "))
print("sum is: ", add_numbers(2,3))
# Out:
# sum is:  5

# %%
def f(x,y,z):
    return (x+y)/z

print("result is: ", f(5,6,7.5))
# Out:
# result is:  1.4666666666666666

# %%
x = 5
y = 7
if x > 5:
    x += 1

y += 1
print(y)
# Out:
# 8

# %%
import numpy as np
a = np.random.randn(100,100)
# %timeit np.dot(a,a) # timeit magic function uses to check execution time
# Out:
# 170 µs ± 6.65 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %pwd
# Out:
# '/work'

# %%
# Magic commands
foo = %pwd
foo
# Out:
# '/work'

# %%
# %quickref
# %magic

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
# matplotlib integration
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(np.random.randn(30).cumsum())

# %%
a = [1,2,3]
b = a
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
def append_element(some_list, element):
    some_list.append(element) # appending element in list

data = [1,2,3]
append_element(data,4)
data
# Out:
# [1, 2, 3, 4]

# %%
# Dynamic references
a = 5
print(type(a))
b = 'foo'
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a = 4.5
b = 2
print('a is {0}, b is {1}'.format(type(a),type(b)))
a / b
# Out:
# a is <class 'float'>, b is <class 'int'>
# 2.25

# %%
a = 5
isinstance(a, int) # isinstance function accept tuple of types if we want to check object's type
b = 4.5
isinstance(b,float)
# Out:
# True

# %%
# Attributes and methods
a = 'foo'
print(a.capitalize())
print(a.upper())
print(a.lower())
print(a.format())
print(a.index('f'))
print(a.find('o'))
print(a.isalnum())
print(a.isalpha())
print(a.istitle())
print(a.isdigit())
print(a.isupper())
print(a.islower())
print(a.isspace())
print(a.replace('o','e'))
# Out:
# Foo
# FOO
# foo
# foo
# 0
# 1
# True
# True
# False
# False
# False
# True
# False
# fee

# %%
a = '---foo---'
print(a.strip('-'))
print(a.lstrip('-'))
print(a.rstrip('-'))
print(a.split())
# Out:
# foo
# foo---
# ---foo
# ['---foo---']

# %%
def isiterable(obj): # isiterable functions returns true for strings
    try:
        iter(obj)
        return True
    except TypeError:
        return False

isiterable('hi')
# Out:
# True

# %%
isiterable(5)
# Out:
# False

# %%
# binary operators

5 - 7
# Out:
# -2

# %%
12 + 21.5
# Out:
# 33.5

# %%
a = [1,2,3]
b = a 
# 2 references refer to the same obj use is keyword
a is b
# Out:
# True

# %%
c = list(a)
# is not also uses to check  2 objects are not same
a is not c
# Out:
# True

# %%
a==c # == is same as is not to compare
# Out:
# True

# %%
a_list = ['foo',2,[6,7]]
a_list[2] = [3,4]
a_list # List is mutable
# Out:
# ['foo', 2, [3, 4]]

# %%
# a = (3,5,(2,6))
# a[1] =  'three'
# (tuples and strings are immutable)

# %%
ival = 25 # int stores arbitrarily large numbers
ival ** 25
# Out:
# 88817841970012523233890533447265625

# %%
a = 3 / 2
a # integer division will yield floating-point
# Out:
# 1.5

# %%
a = 3 // 2 # floor division operator returns integer after division
a
# Out:
# 1

# %%
c = """
Hi hello
hw r u
"""
c.count('\n') # count method to count new line characters
# Out:
# 3

# %%
a  = "this is 690 Data science"
a.replace('690', '690-02')
# Out:
# 'this is 690-02 Data science'

# %%
a = 5.6
s = str(a) # float is converted to string
s
# Out:
# '5.6'

# %%
a = 'python'
list(a)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
a[:3]
# Out:
# 'pyt'

# %%
s = '12\\34' # backslash character \ is an escape character 
print(s)
# Out:
# 12\34

# %%
a = 'Hi '
b = 'Hello'
a+b
# Out:
# 'Hi Hello'

# %%
temp = '{0:.2f}{1:s} costs ${2:d}' #1st argument float with 2 decimal places, 2nd argument str, 3rd argument int
temp.format(4.456,' coffee',5)
# Out:
# '4.46 coffee costs $5'

# %%
# bytes and unicode
bytes_val = b'this is bytes'
bytes_val
# Out:
# b'this is bytes'

# %%
val = 'espanol'
val_utf8 = val.encode('utf-8') # convert unicode string to UTF-8 Bytes (encode)
val_utf8.decode('utf-8') # decode method to get unicode
# Out:
# 'espanol'

# %%
True and False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
# Type casting
s = '3.14'
fval = float(s) # str to float 
type(fval)
# Out:
# float

# %%
int(fval) # convert float to int
# Out:
# 3

# %%
bool(fval)
# Out:
# True

# %%
a = None
a is None
# Out:
# True

# %%
a is not None
# Out:
# False

# %%
type(None)
# Out:
# NoneType

# %%
# Dates and times

from datetime import datetime, date, time
dt = datetime(2021,10,26,13,20,54)
dt.month
# Out:
# 10

# %%
dt.second
# Out:
# 54

# %%
dt.strftime('%m/%d/%y %H:%M:%S') # strftime formats datetime as string
# Out:
# '10/26/21 13:20:54'

# %%
dt1 = datetime(2020,1,13,19,35,45)
delta  = dt1 - dt
delta
# Out:
# datetime.timedelta(days=-652, seconds=22491)

# %%
type(delta)
# Out:
# datetime.timedelta

# %%
# If condition
x=4
if(x<0):
    print('negative')
elif x == 0:
    print('zero')
elif 0<x<5:
    print('positive smaller than 5')
else:
    print('negative & less than 5')
# Out:
# positive smaller than 5

# %%
# for loop
list = [5,10,20,30,33]
count = 0
for i in list:
    if i%2 == 0:
        count += 1
        print(count)
# Out:
# 1
# 2
# 3

# %%
# While loop
i = 1
while i<=5:
    print(i)
    i = i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# range
for i in range(5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
x = 0 
'Non-negative' if x>0 else 'negative' # true-exp if condition else false-exp (Ternary expresion)
# Out:
# 'negative'
